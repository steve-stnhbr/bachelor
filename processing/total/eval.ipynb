# %%
import os
import cv2
import random
import pandas as pd
import tensorflow as tf

# %%
EVAL_AMOUNT = 2
DATASET_DIR = "_data/plant_pathology"

# %%
train_data = pd.read_csv(os.path.join(DATASET_DIR, "train.csv"))

# %%
train_data
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 0        Train_0        0                  0     0     1
# 1        Train_1        0                  1     0     0
# 2        Train_2        1                  0     0     0
# 3        Train_3        0                  0     1     0
# 4        Train_4        1                  0     0     0
# ...          ...      ...                ...   ...   ...
# 1816  Train_1816        0                  0     0     1
# 1817  Train_1817        1                  0     0     0
# 1818  Train_1818        1                  0     0     0
# 1819  Train_1819        0                  0     1     0
# 1820  Train_1820        0                  0     0     1
#
# [1821 rows x 5 columns]

# %%
print(train_data.sum())
print(len(train_data.index))
print(train_data.sum(numeric_only=True).div(len(train_data.index)))
print(train_data.sum(numeric_only=True).sum())
# Out:
# image_id             Train_0Train_1Train_2Train_3Train_4Train_5Trai...
# healthy                                                            516
# multiple_diseases                                                   91
# rust                                                               622
# scab                                                               592
# dtype: object
# 1821
# healthy              0.283361
# multiple_diseases    0.049973
# rust                 0.341571
# scab                 0.325096
# dtype: float64
# 1821

# %%
indices = random.sample(list(train_data.index), k=EVAL_AMOUNT)

# %%
def generate_prediction(img):
    pass

# %%
print(1063 in train_data.index)
# Out:
# True

# %%
import multiprocessing
def execute_in_process(func, args):
    with multiprocessing.get_context("spawn").Pool(1) as pool:
        return pool.apply(func, args)

# %%
def get_patches(masks, image, apply_mask=False, padding=0):
    result = []
    
    for mask in masks:
        if apply_mask:
            image_tmp = image * (mask["segmentation"][:, :, np.newaxis])
        else:
            image_tmp = image
        
        bbox = mask["bbox"]
        x0 = bbox[1]-padding
        if x0 < 0:
            x0 = 0
        x1 = bbox[1]+bbox[3]+padding
        if x1 >= image.shape[0]:
            x1 = image.shape[0] - 1
        y0 = bbox[0]-padding
        if y0 < 0:
            y0 = 0
        y1 = bbox[0]+bbox[2]+padding
        if y1 >= image.shape[1]:
            y1 = image.shape[1] - 1
        
        patch = image_tmp[x0:x1, y0:y1]
        
        if 0 in patch.shape:
            continue
        result.append(patch)
    
    return result

# %% [raw]
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth

# %%
device = "cuda"

# %%
def sam_generate_mask(image):
    import sys
    sys.path.append("..")
    from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

    sam_checkpoint = "sam_vit_h_4b8939.pth"
    model_type = "vit_h"


    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    sam.to(device=device)

    mask_generator = SamAutomaticMaskGenerator(sam)
    masks = mask_generator.generate(image)
    return masks

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.models import resnet50, ResNet50_Weights
class BinaryResnetClassifier(nn.Module):
    def __init__(self, num_classes=1):
        super(BinaryResnetClassifier, self).__init__()
        # Load a pre-trained ResNet model
        self.resnet = resnet50(ResNet50_Weights.IMAGENET1K_V1)  # You can choose any ResNet variant
        # Modify the last fully connected layer
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, num_classes)
        nn.init.xavier_normal_(self.resnet.fc.weight)

    def forward(self, x):
        # Pass the input through the ResNet
        x = self.resnet(x)
        return x
    
import torchvision.transforms.v2 as transforms

tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  
])

def s1_sam_resnet(image):
    #masks = execute_in_process(sam_generate_mask, (image,))
    masks = sam_generate_mask(image)
    patches = get_patches(masks, image)
    resnet = torch.load("../leaf_segmentation/out/leaf_classifier/resnet/resnet_latest.pth")
    resnet = resnet.to(device)
    from PIL import Image
    results = []
    with torch.no_grad():
        for patch in patches:
            input = tf(Image.fromarray(patch)).unsqueeze(0).to(device)
            result = torch.sigmoid(resnet(input)).cpu().item()

            results.append(result)
    del resnet
    PROBABILITY_THRESHOLD = .1
    masks_filtered = [mask for mask, result in zip(masks,results) if result > PROBABILITY_THRESHOLD]
    return masks_filtered
# Out:
# /home/stefan.steinheber/.conda/envs/total/lib/python3.12/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
def s1_sam_yolo(image):
    from ultralytics import YOLO, checks
    masks = sam_generate_mask(image)
    patches = get_patches(masks, image)
    model = YOLO("../leaf_segmentation/out/yolo_urban_street/train/weights/best.pt")
    model.info()
    results_yolo = []
    for i, patch in enumerate(patches):
        result = model.predict(patch)
        results_yolo.append(1 if result[0].masks is not None and len(result[0].masks) > 0 else 0)
        masks[i]["patch"] = patch
        masks[i]["leaf_probability"] = 1 if result[0].masks is not None and len(result[0].masks) > 0 else 0
    masks_filtered = [mask for mask, result in zip(masks,results_yolo) if result > 0]
    return masks_filtered

# %%
def s1_mask_rcnn(image):
    pass

# %%
stage1_dict = {
    "SAM + YOLOv8": s1_sam_yolo,
    "SAM + ResNet": s1_sam_resnet,
    "Mask R-CNN": s1_mask_rcnn
}

# %%
import keras

# %%
def get_latest_checkpoint(dir):
    if not os.path.isdir(dir):
        return None
    ckpts = [file for file in os.listdir(dir) if file.endswith("keras")]
    ckpts.sort()
    return os.path.join(dir, ckpts[-1])

# %%
PROB_THRESHOLD = .8

# %%
results_df = pd.DataFrame()

# %%
import torch

# %%
stage1_results = {}
for stage1_name, stage1_model in stage1_dict.items():
    stage1_results[stage1_name] = []
    for index in indices:
        gt_healthy = bool(train_data.loc[index]["healthy"])
        img = cv2.imread(os.path.join(DATASET_DIR, "images", train_data.loc[index]["image_id"] + ".jpg"))
        with torch.no_grad():
            leaf_masks = stage1_model(img)
            stage1_results[stage1_name].append(leaf_masks)
        torch.cuda.empty_cache()
# Out:
# YOLOv8m-seg summary: 355 layers, 24,605,027 parameters, 0 gradients, 99.2 GFLOPs
#
# 0: 480x640 1 leaf, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 leaf, 9.7ms
# Speed: 1.6ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x224 (no detections), 10.3ms
# Speed: 1.2ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 448x640 1 leaf, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x320 1 leaf, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 384x640 1 leaf, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 1 leaf, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 640x384 1 leaf, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x640 1 leaf, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x448 (no detections), 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 480x640 1 leaf, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 leaf, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 1 leaf, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x544 1 leaf, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x512 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 352x640 1 leaf, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 416x640 1 leaf, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 leaf, 14.1ms
# Speed: 1.3ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 leaf, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x544 1 leaf, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x96 (no detections), 13.7ms
# Speed: 0.6ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 96)
#
# 0: 608x640 1 leaf, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 320x640 1 leaf, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 640x416 1 leaf, 9.1ms
# Speed: 1.4ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 224x640 1 leaf, 9.3ms
# Speed: 1.1ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 480x640 1 leaf, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 288x640 1 leaf, 9.2ms
# Speed: 1.3ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x480 1 leaf, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 384x640 1 leaf, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 leaf, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x256 1 leaf, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x384 1 leaf, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 608x640 1 leaf, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 352x640 1 leaf, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 512x640 1 leaf, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 448x640 1 leaf, 9.2ms
# Speed: 1.4ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 leaf, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 1 leaf, 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 416x640 1 leaf, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x576 1 leaf, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
# YOLOv8m-seg summary: 355 layers, 24,605,027 parameters, 0 gradients, 99.2 GFLOPs
#
# 0: 512x640 1 leaf, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x544 1 leaf, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x416 (no detections), 13.1ms
# Speed: 1.2ms preprocess, 13.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x480 1 leaf, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 leaf, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 288x640 1 leaf, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 256x640 1 leaf, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 640x544 (no detections), 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 384x640 1 leaf, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 96x640 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 640)
#
# 0: 480x640 1 leaf, 12.4ms
# Speed: 1.5ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 1 leaf, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 1 leaf, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 (no detections), 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 leaf, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x256 (no detections), 9.7ms
# Speed: 0.9ms preprocess, 9.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 1 leaf, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 leaf, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 448x640 1 leaf, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 160x640 (no detections), 9.8ms
# Speed: 0.7ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 480x640 1 leaf, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 512x640 1 leaf, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 448x640 (no detections), 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 576x640 1 leaf, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 128x640 (no detections), 12.5ms
# Speed: 0.7ms preprocess, 12.5ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 320x640 1 leaf, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 leaf, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 576x640 1 leaf, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x352 (no detections), 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 448x640 1 leaf, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 512x640 1 leaf, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 leaf, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 leaf, 12.4ms
# Speed: 1.3ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 288x640 1 leaf, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 224x640 (no detections), 13.7ms
# Speed: 0.9ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 544x640 1 leaf, 13.6ms
# Speed: 1.8ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 leaf, 14.3ms
# Speed: 1.3ms preprocess, 14.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 leaf, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x608 (no detections), 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 160x640 1 leaf, 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 544x640 1 leaf, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 1 leaf, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x576 1 leaf, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x192 1 leaf, 9.8ms
# Speed: 0.9ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 192)
#
# 0: 640x288 1 leaf, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 288x640 1 leaf, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 1 leaf, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 160x640 (no detections), 9.6ms
# Speed: 0.8ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 640x576 1 leaf, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 416x640 1 leaf, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x512 1 leaf, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 224x640 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 640x640 1 leaf, 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 leaf, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 1 leaf, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x512 1 leaf, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 256x640 1 leaf, 9.3ms
# Speed: 1.1ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 608x640 1 leaf, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 leaf, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 448x640 1 leaf, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x352 1 leaf, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x544 1 leaf, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x608 1 leaf, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 320x640 1 leaf, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 512x640 1 leaf, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 leaf, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 352x640 1 leaf, 10.2ms
# Speed: 1.2ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 640x640 1 leaf, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 leaf, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x576 1 leaf, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x544 1 leaf, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x352 1 leaf, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x480 (no detections), 9.3ms
# Speed: 1.2ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 352x640 1 leaf, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 leaf, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 leaf, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 leaf, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 320x640 1 leaf, 9.1ms
# Speed: 1.1ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 448x640 1 leaf, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 leaf, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
stage1_results
# Out:
# {'SAM + YOLOv8': [[{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1023044,
#     'bbox': [416, 110, 1464, 1052],
#     'predicted_iou': 1.036436915397644,
#     'point_coords': [[1248.0, 703.828125]],
#     'stability_score': 0.9924018979072571,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 67, 103, 119],
#             [ 67, 103, 119],
#             [ 67, 103, 119],
#             ...,
#             [187, 228, 220],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            [[ 69, 103, 119],
#             [ 69, 103, 119],
#             [ 69, 103, 119],
#             ...,
#             [187, 228, 220],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            [[ 69, 102, 118],
#             [ 69, 102, 118],
#             [ 69, 102, 118],
#             ...,
#             [186, 229, 218],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            ...,
#
#            [[ 74, 151, 123],
#             [ 74, 152, 121],
#             [ 73, 150, 122],
#             ...,
#             [ 94, 166, 153],
#             [ 94, 166, 153],
#             [ 94, 166, 153]],
#
#            [[ 78, 153, 125],
#             [ 78, 153, 125],
#             [ 78, 153, 125],
#             ...,
#             [ 94, 166, 153],
#             [ 94, 166, 153],
#             [ 94, 166, 153]],
#
#            [[ 78, 153, 125],
#             [ 78, 153, 125],
#             [ 78, 153, 125],
#             ...,
#             [ 93, 165, 152],
#             [ 94, 166, 153],
#             [ 94, 166, 153]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 66540,
#     'bbox': [1362, 0, 403, 267],
#     'predicted_iou': 1.0057369470596313,
#     'point_coords': [[1440.0, 21.328125]],
#     'stability_score': 0.9905040860176086,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            [[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            [[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            ...,
#
#            [[ 83, 142, 104],
#             [ 85, 142, 104],
#             [ 85, 142, 104],
#             ...,
#             [ 38,  80,  69],
#             [ 39,  81,  70],
#             [ 38,  80,  69]],
#
#            [[ 87, 144, 106],
#             [ 86, 143, 105],
#             [ 85, 142, 104],
#             ...,
#             [ 38,  80,  69],
#             [ 39,  81,  70],
#             [ 38,  80,  69]],
#
#            [[ 89, 146, 108],
#             [ 88, 145, 107],
#             [ 87, 144, 106],
#             ...,
#             [ 38,  80,  69],
#             [ 38,  80,  69],
#             [ 38,  80,  69]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 106647,
#     'bbox': [0, 899, 623, 428],
#     'predicted_iou': 0.9949654340744019,
#     'point_coords': [[480.0, 959.765625]],
#     'stability_score': 0.9745847582817078,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 54, 119,  98],
#             [ 55, 120,  99],
#             [ 55, 120,  99],
#             ...,
#             [ 46, 121,  77],
#             [ 48, 121,  75],
#             [ 47, 119,  76]],
#
#            [[ 56, 121, 100],
#             [ 56, 121, 100],
#             [ 57, 122, 101],
#             ...,
#             [ 46, 122,  80],
#             [ 47, 122,  78],
#             [ 45, 119,  77]],
#
#            [[ 57, 122, 101],
#             [ 58, 123, 102],
#             [ 59, 124, 103],
#             ...,
#             [ 49, 125,  84],
#             [ 47, 123,  81],
#             [ 45, 121,  79]],
#
#            ...,
#
#            [[129, 183, 176],
#             [129, 183, 176],
#             [129, 183, 176],
#             ...,
#             [ 45, 115,  84],
#             [ 47, 117,  86],
#             [ 47, 120,  88]],
#
#            [[127, 181, 174],
#             [126, 180, 173],
#             [126, 180, 173],
#             ...,
#             [ 45, 115,  84],
#             [ 48, 118,  87],
#             [ 48, 121,  89]],
#
#            [[123, 177, 170],
#             [122, 176, 169],
#             [122, 176, 169],
#             ...,
#             [ 45, 115,  84],
#             [ 48, 118,  87],
#             [ 48, 121,  89]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 52478,
#     'bbox': [0, 377, 220, 476],
#     'predicted_iou': 0.9941893815994263,
#     'point_coords': [[32.0, 746.484375]],
#     'stability_score': 0.9825999736785889,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 63, 163, 145],
#             [ 72, 171, 151],
#             [ 81, 173, 156],
#             ...,
#             [ 31,  53,  58],
#             [ 32,  54,  59],
#             [ 33,  55,  60]],
#
#            [[ 56, 157, 136],
#             [ 67, 167, 145],
#             [ 79, 174, 154],
#             ...,
#             [ 32,  54,  59],
#             [ 31,  56,  60],
#             [ 31,  56,  60]],
#
#            [[ 48, 148, 126],
#             [ 59, 157, 133],
#             [ 71, 166, 145],
#             ...,
#             [ 33,  55,  60],
#             [ 31,  56,  60],
#             [ 32,  57,  61]],
#
#            ...,
#
#            [[ 47, 128, 109],
#             [ 47, 129, 107],
#             [ 48, 128, 105],
#             ...,
#             [ 70, 135, 120],
#             [ 70, 135, 120],
#             [ 70, 135, 120]],
#
#            [[ 48, 127, 108],
#             [ 48, 127, 108],
#             [ 47, 126, 105],
#             ...,
#             [ 71, 136, 121],
#             [ 71, 136, 121],
#             [ 71, 136, 121]],
#
#            [[ 49, 125, 107],
#             [ 48, 124, 106],
#             [ 47, 124, 103],
#             ...,
#             [ 72, 137, 122],
#             [ 72, 137, 122],
#             [ 72, 137, 122]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#            [False, False, False, ...,  True,  True,  True],
#            [False, False, False, ...,  True,  True,  True],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9946,
#     'bbox': [1887, 0, 160, 94],
#     'predicted_iou': 0.9912731051445007,
#     'point_coords': [[1952.0, 21.328125]],
#     'stability_score': 0.9862275719642639,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 69, 126,  95],
#             [ 68, 126,  97],
#             [ 69, 129,  99],
#             ...,
#             [123, 207, 183],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            [[ 68, 125,  94],
#             [ 68, 126,  97],
#             [ 68, 128,  98],
#             ...,
#             [123, 207, 183],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            [[ 67, 124,  93],
#             [ 68, 126,  97],
#             [ 69, 127,  98],
#             ...,
#             [122, 206, 182],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            ...,
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 83, 158, 126],
#             [ 81, 157, 125],
#             [ 82, 157, 125]],
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 84, 157, 125],
#             [ 82, 157, 125],
#             [ 83, 156, 124]],
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 85, 158, 126],
#             [ 84, 157, 125],
#             [ 84, 157, 125]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 173063,
#     'bbox': [572, 0, 1201, 370],
#     'predicted_iou': 0.9882864356040955,
#     'point_coords': [[672.0, 63.984375]],
#     'stability_score': 0.9787916541099548,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 60, 139, 100],
#             [ 57, 136,  97],
#             [ 54, 131,  93]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 61, 140, 101],
#             [ 57, 136,  97],
#             [ 55, 132,  94]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 39,  84,  65],
#             ...,
#             [ 61, 139, 102],
#             [ 58, 136,  99],
#             [ 55, 132,  94]],
#
#            ...,
#
#            [[ 55,  93, 111],
#             [ 54,  94, 112],
#             [ 56,  94, 112],
#             ...,
#             [ 90, 167, 129],
#             [ 91, 168, 130],
#             [ 91, 168, 130]],
#
#            [[ 57,  93, 109],
#             [ 55,  94, 109],
#             [ 57,  93, 109],
#             ...,
#             [ 91, 166, 128],
#             [ 92, 167, 129],
#             [ 92, 166, 130]],
#
#            [[ 57,  94, 108],
#             [ 57,  94, 108],
#             [ 57,  94, 108],
#             ...,
#             [ 92, 167, 129],
#             [ 92, 167, 129],
#             [ 94, 166, 130]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#            [ True,  True,  True, ..., False, False, False],
#            [ True,  True,  True, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 40697,
#     'bbox': [0, 0, 202, 365],
#     'predicted_iou': 0.9865459203720093,
#     'point_coords': [[32.0, 191.953125]],
#     'stability_score': 0.9808867573738098,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            [[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            [[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            ...,
#
#            [[ 56, 103,  87],
#             [ 53, 100,  84],
#             [ 50,  97,  81],
#             ...,
#             [ 39,  49,  59],
#             [ 37,  47,  57],
#             [ 37,  47,  57]],
#
#            [[ 56, 103,  87],
#             [ 54, 101,  85],
#             [ 50,  97,  81],
#             ...,
#             [ 38,  48,  58],
#             [ 37,  47,  57],
#             [ 37,  47,  57]],
#
#            [[ 59, 104,  88],
#             [ 57, 102,  86],
#             [ 53,  97,  84],
#             ...,
#             [ 38,  48,  58],
#             [ 37,  47,  57],
#             [ 36,  46,  56]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 172784,
#     'bbox': [572, 0, 829, 368],
#     'predicted_iou': 0.9853312373161316,
#     'point_coords': [[1248.0, 63.984375]],
#     'stability_score': 0.9801424741744995,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 59, 121,  85]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 59, 121,  85]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 39,  84,  65],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 60, 121,  87]],
#
#            ...,
#
#            [[ 53,  93, 112],
#             [ 53,  93, 112],
#             [ 53,  93, 112],
#             ...,
#             [ 87, 150, 110],
#             [ 86, 152, 111],
#             [ 88, 156, 115]],
#
#            [[ 53,  93, 112],
#             [ 53,  93, 112],
#             [ 54,  94, 113],
#             ...,
#             [ 88, 151, 111],
#             [ 86, 152, 111],
#             [ 85, 153, 112]],
#
#            [[ 55,  93, 111],
#             [ 54,  94, 112],
#             [ 56,  94, 112],
#             ...,
#             [ 91, 153, 113],
#             [ 90, 153, 113],
#             [ 87, 153, 112]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 34412,
#     'bbox': [940, 1167, 275, 197],
#     'predicted_iou': 0.9822528958320618,
#     'point_coords': [[1056.0, 1215.703125]],
#     'stability_score': 0.9664067029953003,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 24, 100,  58],
#             [ 24, 100,  59],
#             [ 24, 100,  59],
#             ...,
#             [114, 159, 163],
#             [113, 158, 162],
#             [112, 157, 161]],
#
#            [[ 31, 100,  63],
#             [ 32, 101,  64],
#             [ 32, 101,  64],
#             ...,
#             [116, 158, 163],
#             [116, 158, 163],
#             [115, 157, 162]],
#
#            [[ 35,  99,  64],
#             [ 35,  99,  64],
#             [ 36, 100,  65],
#             ...,
#             [117, 159, 164],
#             [116, 158, 163],
#             [116, 158, 163]],
#
#            ...,
#
#            [[ 65, 132, 101],
#             [ 66, 133, 102],
#             [ 68, 135, 104],
#             ...,
#             [103, 163, 157],
#             [103, 163, 157],
#             [103, 162, 158]],
#
#            [[ 65, 132, 101],
#             [ 65, 132, 101],
#             [ 67, 134, 103],
#             ...,
#             [103, 163, 157],
#             [103, 163, 157],
#             [103, 162, 158]],
#
#            [[ 64, 131, 100],
#             [ 65, 132, 101],
#             [ 67, 134, 103],
#             ...,
#             [104, 164, 158],
#             [103, 163, 157],
#             [103, 162, 158]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1185650,
#     'bbox': [0, 110, 1873, 1217],
#     'predicted_iou': 0.9766499996185303,
#     'point_coords': [[1632.0, 746.484375]],
#     'stability_score': 0.958342432975769,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40, 108,  83],
#             [ 40, 108,  83],
#             [ 40, 109,  82],
#             ...,
#             [180, 227, 218],
#             [180, 227, 218],
#             [186, 229, 220]],
#
#            [[ 40, 108,  83],
#             [ 38, 109,  83],
#             [ 40, 109,  82],
#             ...,
#             [178, 228, 218],
#             [180, 227, 218],
#             [184, 229, 220]],
#
#            [[ 39, 110,  83],
#             [ 37, 111,  83],
#             [ 38, 109,  82],
#             ...,
#             [176, 228, 218],
#             [178, 228, 218],
#             [180, 228, 216]],
#
#            ...,
#
#            [[129, 183, 176],
#             [129, 183, 176],
#             [129, 183, 176],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]],
#
#            [[127, 181, 174],
#             [126, 180, 173],
#             [126, 180, 173],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]],
#
#            [[123, 177, 170],
#             [122, 176, 169],
#             [122, 176, 169],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 14090,
#     'bbox': [1690, 122, 127, 174],
#     'predicted_iou': 0.9752795696258545,
#     'point_coords': [[1760.0, 149.296875]],
#     'stability_score': 0.9783264398574829,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[111, 175, 163],
#             [113, 177, 165],
#             [112, 178, 166],
#             ...,
#             [ 72, 157, 137],
#             [ 73, 158, 138],
#             [ 75, 162, 142]],
#
#            [[111, 175, 163],
#             [113, 177, 165],
#             [112, 178, 166],
#             ...,
#             [ 72, 157, 137],
#             [ 72, 157, 137],
#             [ 75, 162, 142]],
#
#            [[111, 175, 163],
#             [112, 176, 164],
#             [111, 177, 165],
#             ...,
#             [ 71, 156, 136],
#             [ 72, 157, 137],
#             [ 77, 162, 142]],
#
#            ...,
#
#            [[ 27,  97,  60],
#             [ 27,  97,  60],
#             [ 28,  98,  61],
#             ...,
#             [ 63, 160, 134],
#             [ 63, 160, 134],
#             [ 70, 167, 141]],
#
#            [[ 29,  98,  61],
#             [ 30,  99,  62],
#             [ 31, 100,  63],
#             ...,
#             [ 70, 169, 143],
#             [ 69, 170, 144],
#             [ 78, 179, 154]],
#
#            [[ 27,  96,  59],
#             [ 27,  96,  59],
#             [ 28,  97,  60],
#             ...,
#             [ 78, 179, 153],
#             [ 80, 181, 155],
#             [ 87, 189, 164]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 404451,
#     'bbox': [1280, 456, 767, 904],
#     'predicted_iou': 0.9751681685447693,
#     'point_coords': [[1952.0, 789.140625]],
#     'stability_score': 0.9565773606300354,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 98, 156, 115],
#             [100, 158, 117],
#             [103, 161, 120],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            [[ 98, 156, 115],
#             [ 99, 157, 116],
#             [101, 159, 118],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            [[ 98, 158, 117],
#             [ 98, 158, 117],
#             [ 98, 158, 117],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            ...,
#
#            [[142, 180, 204],
#             [142, 180, 204],
#             [140, 181, 204],
#             ...,
#             [ 87, 174, 140],
#             [ 87, 174, 140],
#             [ 87, 174, 140]],
#
#            [[140, 181, 204],
#             [140, 181, 204],
#             [140, 181, 204],
#             ...,
#             [ 86, 173, 139],
#             [ 87, 174, 140],
#             [ 87, 174, 140]],
#
#            [[140, 181, 204],
#             [140, 181, 204],
#             [140, 181, 204],
#             ...,
#             [ 86, 173, 139],
#             [ 87, 174, 140],
#             [ 87, 174, 140]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 54606,
#     'bbox': [239, 1181, 361, 182],
#     'predicted_iou': 0.9717997908592224,
#     'point_coords': [[288.0, 1301.015625]],
#     'stability_score': 0.9778668284416199,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 66, 143, 115],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [134, 184, 180],
#             [133, 183, 179],
#             [133, 183, 179]],
#
#            [[ 64, 144, 113],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [134, 184, 180],
#             [134, 184, 180],
#             [133, 183, 179]],
#
#            [[ 64, 144, 113],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [135, 185, 181],
#             [134, 184, 180],
#             [134, 184, 180]],
#
#            ...,
#
#            [[ 59, 132, 100],
#             [ 57, 132, 100],
#             [ 56, 132, 100],
#             ...,
#             [ 29,  87,  58],
#             [ 32,  92,  62],
#             [ 32,  94,  64]],
#
#            [[ 59, 131, 101],
#             [ 57, 131, 101],
#             [ 57, 131, 101],
#             ...,
#             [ 30,  90,  60],
#             [ 33,  93,  63],
#             [ 31,  95,  65]],
#
#            [[ 59, 131, 101],
#             [ 57, 131, 101],
#             [ 57, 131, 101],
#             ...,
#             [ 31,  91,  61],
#             [ 35,  95,  65],
#             [ 33,  97,  67]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 44175,
#     'bbox': [1106, 1153, 333, 210],
#     'predicted_iou': 0.9715837240219116,
#     'point_coords': [[1248.0, 1215.703125]],
#     'stability_score': 0.9528433084487915,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 75, 187, 157],
#             [ 75, 181, 158],
#             [ 74, 169, 155],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 35,  90,  73]],
#
#            [[ 85, 195, 167],
#             [ 85, 188, 167],
#             [ 81, 175, 164],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 35,  90,  73]],
#
#            [[ 90, 196, 173],
#             [ 91, 190, 174],
#             [ 87, 178, 169],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 36,  91,  74]],
#
#            ...,
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 55, 146, 113],
#             [ 54, 148, 114],
#             [ 54, 148, 114]],
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 53, 147, 113],
#             [ 54, 148, 114],
#             [ 54, 148, 114]],
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 54, 148, 114],
#             [ 54, 148, 114],
#             [ 54, 148, 114]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9005,
#     'bbox': [276, 1181, 165, 94],
#     'predicted_iou': 0.9704208374023438,
#     'point_coords': [[352.0, 1258.359375]],
#     'stability_score': 0.9735687375068665,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 59, 135, 104],
#             [ 59, 135, 104],
#             [ 59, 134, 106],
#             ...,
#             [ 89, 160, 134],
#             [ 89, 160, 134],
#             [ 89, 159, 136]],
#
#            [[ 59, 135, 104],
#             [ 59, 135, 104],
#             [ 58, 133, 105],
#             ...,
#             [ 89, 160, 134],
#             [ 89, 160, 134],
#             [ 89, 159, 136]],
#
#            [[ 59, 135, 104],
#             [ 58, 134, 103],
#             [ 58, 133, 105],
#             ...,
#             [ 87, 160, 134],
#             [ 87, 160, 134],
#             [ 87, 159, 136]],
#
#            ...,
#
#            [[ 86, 160, 132],
#             [ 89, 159, 128],
#             [ 91, 160, 127],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]],
#
#            [[ 85, 159, 129],
#             [ 87, 157, 126],
#             [ 89, 158, 125],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]],
#
#            [[ 83, 157, 127],
#             [ 86, 156, 125],
#             [ 87, 156, 123],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 28032,
#     'bbox': [0, 857, 236, 164],
#     'predicted_iou': 0.9703064560890198,
#     'point_coords': [[96.0, 874.453125]],
#     'stability_score': 0.9763349294662476,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 51, 116, 101],
#             [ 50, 115, 100],
#             [ 48, 113,  97],
#             ...,
#             [ 56, 116,  98],
#             [ 57, 115,  97],
#             [ 55, 113,  95]],
#
#            [[ 49, 111,  99],
#             [ 47, 109,  95],
#             [ 45, 108,  92],
#             ...,
#             [ 55, 117,  99],
#             [ 56, 116,  98],
#             [ 54, 114,  96]],
#
#            [[ 46, 106,  95],
#             [ 45, 105,  94],
#             [ 43, 104,  90],
#             ...,
#             [ 56, 118, 100],
#             [ 57, 117,  99],
#             [ 55, 115,  97]],
#
#            ...,
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  55,  32],
#             [ 26,  55,  32],
#             [ 26,  55,  32]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 25,  54,  31],
#             [ 26,  55,  32],
#             [ 26,  55,  32]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 25,  54,  31],
#             [ 25,  54,  31],
#             [ 26,  55,  32]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 48764,
#     'bbox': [1753, 462, 252, 309],
#     'predicted_iou': 0.9699550867080688,
#     'point_coords': [[1760.0, 618.515625]],
#     'stability_score': 0.9633088707923889,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 39, 133,  86],
#             [ 39, 133,  86],
#             [ 39, 133,  86],
#             ...,
#             [ 91, 198, 159],
#             [ 91, 198, 159],
#             [ 91, 198, 159]],
#
#            [[ 36, 132,  85],
#             [ 36, 132,  85],
#             [ 39, 133,  86],
#             ...,
#             [ 91, 199, 157],
#             [ 91, 198, 159],
#             [ 91, 198, 159]],
#
#            [[ 34, 133,  85],
#             [ 31, 130,  82],
#             [ 33, 129,  82],
#             ...,
#             [ 89, 200, 156],
#             [ 89, 199, 157],
#             [ 89, 199, 157]],
#
#            ...,
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 73, 150, 112],
#             [ 73, 152, 113],
#             [ 75, 152, 114]],
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 72, 151, 112],
#             [ 72, 151, 112],
#             [ 73, 152, 113]],
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 71, 150, 111],
#             [ 72, 151, 112],
#             [ 73, 152, 113]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 35179,
#     'bbox': [0, 792, 243, 229],
#     'predicted_iou': 0.9653553366661072,
#     'point_coords': [[224.0, 831.796875]],
#     'stability_score': 0.9643674492835999,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 60, 135, 107],
#             [ 58, 135, 107],
#             [ 59, 136, 109],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            [[ 60, 135, 107],
#             [ 60, 135, 107],
#             [ 60, 134, 108],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            [[ 60, 134, 106],
#             [ 59, 134, 106],
#             [ 60, 135, 107],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            ...,
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9215,
#     'bbox': [1406, 1288, 166, 76],
#     'predicted_iou': 0.9636751413345337,
#     'point_coords': [[1440.0, 1343.671875]],
#     'stability_score': 0.9803119897842407,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[140, 197, 198],
#             [138, 195, 196],
#             [138, 195, 197],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            [[140, 197, 198],
#             [138, 195, 196],
#             [137, 194, 196],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            [[140, 197, 198],
#             [138, 195, 196],
#             [137, 194, 196],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            ...,
#
#            [[ 60, 137, 116],
#             [ 60, 137, 116],
#             [ 62, 137, 115],
#             ...,
#             [ 44, 101,  76],
#             [ 43, 100,  75],
#             [ 41,  98,  73]],
#
#            [[ 61, 138, 117],
#             [ 60, 137, 116],
#             [ 62, 137, 115],
#             ...,
#             [ 43, 100,  75],
#             [ 42,  99,  74],
#             [ 41,  98,  73]],
#
#            [[ 61, 138, 117],
#             [ 61, 138, 117],
#             [ 63, 138, 116],
#             ...,
#             [ 43, 100,  75],
#             [ 42,  99,  74],
#             [ 41,  98,  73]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 15705,
#     'bbox': [553, 1149, 136, 215],
#     'predicted_iou': 0.9624653458595276,
#     'point_coords': [[672.0, 1301.015625]],
#     'stability_score': 0.9720284342765808,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 99, 174, 153],
#             [100, 175, 154],
#             [101, 176, 155],
#             ...,
#             [ 79, 129, 111],
#             [ 77, 129, 111],
#             [ 78, 130, 112]],
#
#            [[ 99, 174, 153],
#             [100, 175, 154],
#             [101, 176, 155],
#             ...,
#             [ 80, 130, 112],
#             [ 78, 130, 112],
#             [ 78, 130, 112]],
#
#            [[ 99, 174, 153],
#             [102, 174, 154],
#             [103, 175, 155],
#             ...,
#             [ 80, 130, 112],
#             [ 78, 130, 112],
#             [ 76, 131, 112]],
#
#            ...,
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 41, 100,  69],
#             [ 41, 100,  69],
#             [ 43,  97,  68]],
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 41, 100,  69],
#             [ 41, 100,  69],
#             [ 43,  97,  68]],
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 40,  99,  68],
#             [ 40,  99,  68],
#             [ 43,  97,  68]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 55768,
#     'bbox': [0, 1181, 601, 182],
#     'predicted_iou': 0.9620964527130127,
#     'point_coords': [[544.0, 1215.703125]],
#     'stability_score': 0.9600830674171448,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 35, 100,  79],
#             [ 35, 100,  79],
#             [ 35, 100,  78],
#             ...,
#             [133, 183, 179],
#             [133, 183, 179],
#             [131, 182, 175]],
#
#            [[ 34,  99,  77],
#             [ 34,  99,  77],
#             [ 34,  99,  77],
#             ...,
#             [134, 184, 180],
#             [133, 183, 179],
#             [132, 183, 176]],
#
#            [[ 33,  98,  76],
#             [ 33,  98,  76],
#             [ 33,  98,  76],
#             ...,
#             [134, 184, 180],
#             [134, 184, 180],
#             [132, 183, 176]],
#
#            ...,
#
#            [[ 31, 102,  76],
#             [ 32, 103,  77],
#             [ 32, 103,  77],
#             ...,
#             [ 32,  92,  62],
#             [ 32,  94,  64],
#             [ 34,  98,  68]],
#
#            [[ 33, 101,  76],
#             [ 34, 102,  77],
#             [ 34, 102,  77],
#             ...,
#             [ 33,  93,  63],
#             [ 31,  95,  65],
#             [ 35,  99,  69]],
#
#            [[ 33, 101,  76],
#             [ 33, 101,  76],
#             [ 34, 102,  77],
#             ...,
#             [ 35,  95,  65],
#             [ 33,  97,  67],
#             [ 36, 100,  70]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17411,
#     'bbox': [264, 723, 178, 126],
#     'predicted_iou': 0.9590465426445007,
#     'point_coords': [[288.0, 746.484375]],
#     'stability_score': 0.9686352014541626,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[100, 139, 131],
#             [100, 139, 131],
#             [ 99, 138, 130],
#             ...,
#             [ 33, 111,  74],
#             [ 35, 113,  76],
#             [ 35, 114,  75]],
#
#            [[100, 139, 131],
#             [100, 139, 131],
#             [100, 139, 131],
#             ...,
#             [ 33, 110,  73],
#             [ 33, 112,  73],
#             [ 33, 112,  73]],
#
#            [[101, 140, 132],
#             [100, 139, 131],
#             [100, 139, 131],
#             ...,
#             [ 32, 109,  72],
#             [ 32, 111,  72],
#             [ 32, 111,  72]],
#
#            ...,
#
#            [[ 31,  70,  48],
#             [ 31,  70,  48],
#             [ 31,  70,  48],
#             ...,
#             [ 36,  83,  51],
#             [ 33,  80,  48],
#             [ 33,  80,  48]],
#
#            [[ 31,  70,  49],
#             [ 31,  70,  48],
#             [ 31,  70,  49],
#             ...,
#             [ 36,  83,  51],
#             [ 35,  79,  48],
#             [ 32,  79,  47]],
#
#            [[ 29,  69,  51],
#             [ 29,  70,  49],
#             [ 30,  70,  52],
#             ...,
#             [ 35,  80,  47],
#             [ 38,  81,  48],
#             [ 35,  80,  47]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 15150,
#     'bbox': [675, 1107, 376, 161],
#     'predicted_iou': 0.9559239745140076,
#     'point_coords': [[864.0, 1173.046875]],
#     'stability_score': 0.9668028354644775,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 53, 106,  86],
#             [ 56, 107,  87],
#             [ 57, 108,  88],
#             ...,
#             [ 24, 105,  60],
#             [ 24, 105,  60],
#             [ 23, 104,  59]],
#
#            [[ 54, 104,  86],
#             [ 55, 105,  87],
#             [ 56, 106,  88],
#             ...,
#             [ 26, 105,  61],
#             [ 26, 105,  61],
#             [ 25, 104,  60]],
#
#            [[ 54, 104,  86],
#             [ 55, 105,  87],
#             [ 55, 105,  87],
#             ...,
#             [ 26, 105,  61],
#             [ 27, 104,  60],
#             [ 27, 104,  60]],
#
#            ...,
#
#            [[ 63, 145, 103],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [130, 186, 165],
#             [130, 186, 165],
#             [133, 186, 166]],
#
#            [[ 63, 144, 105],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [131, 187, 166],
#             [131, 187, 166],
#             [133, 186, 166]],
#
#            [[ 63, 144, 105],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [132, 188, 167],
#             [132, 188, 167],
#             [134, 187, 167]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 111786,
#     'bbox': [129, 182, 367, 512],
#     'predicted_iou': 0.9550802111625671,
#     'point_coords': [[288.0, 319.921875]],
#     'stability_score': 0.9624460339546204,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 93, 127, 133],
#             [ 96, 130, 136],
#             [ 99, 133, 139],
#             ...,
#             [ 54,  85, 100],
#             [ 53,  84,  99],
#             [ 53,  84,  99]],
#
#            [[ 95, 129, 135],
#             [ 98, 132, 138],
#             [101, 135, 141],
#             ...,
#             [ 54,  85, 100],
#             [ 53,  84,  99],
#             [ 53,  84,  99]],
#
#            [[ 96, 128, 134],
#             [100, 132, 138],
#             [103, 135, 141],
#             ...,
#             [ 54,  85, 100],
#             [ 52,  83,  98],
#             [ 52,  83,  98]],
#
#            ...,
#
#            [[ 32,  99,  60],
#             [ 33, 100,  61],
#             [ 33, 100,  61],
#             ...,
#             [ 28,  92,  57],
#             [ 26,  90,  55],
#             [ 25,  89,  54]],
#
#            [[ 33, 100,  61],
#             [ 33, 100,  61],
#             [ 33, 100,  61],
#             ...,
#             [ 29,  93,  57],
#             [ 27,  91,  55],
#             [ 25,  89,  53]],
#
#            [[ 33, 100,  61],
#             [ 34, 101,  62],
#             [ 34, 101,  62],
#             ...,
#             [ 31,  95,  59],
#             [ 29,  93,  57],
#             [ 27,  92,  53]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17849,
#     'bbox': [38, 798, 360, 206],
#     'predicted_iou': 0.9469700455665588,
#     'point_coords': [[288.0, 959.765625]],
#     'stability_score': 0.9567816853523254,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 51, 147, 106],
#             [ 51, 147, 106],
#             [ 56, 148, 107],
#             ...,
#             [ 35, 103,  62],
#             [ 35, 103,  62],
#             [ 35, 103,  62]],
#
#            [[ 53, 147, 106],
#             [ 53, 147, 106],
#             [ 56, 148, 107],
#             ...,
#             [ 35, 103,  62],
#             [ 35, 102,  63],
#             [ 34, 102,  61]],
#
#            [[ 55, 147, 106],
#             [ 57, 146, 106],
#             [ 59, 148, 109],
#             ...,
#             [ 32, 102,  62],
#             [ 32, 101,  64],
#             [ 31, 101,  61]],
#
#            ...,
#
#            [[ 48, 100,  77],
#             [ 48, 100,  77],
#             [ 45,  97,  74],
#             ...,
#             [ 61, 131, 108],
#             [ 61, 132, 106],
#             [ 61, 132, 106]],
#
#            [[ 43,  95,  71],
#             [ 44,  96,  72],
#             [ 43,  93,  69],
#             ...,
#             [ 60, 132, 109],
#             [ 60, 133, 107],
#             [ 60, 133, 107]],
#
#            [[ 39,  91,  67],
#             [ 40,  92,  68],
#             [ 39,  89,  65],
#             ...,
#             [ 61, 133, 110],
#             [ 61, 134, 108],
#             [ 61, 134, 108]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17989,
#     'bbox': [1753, 1230, 160, 134],
#     'predicted_iou': 0.9417983889579773,
#     'point_coords': [[1888.0, 1343.671875]],
#     'stability_score': 0.9593504667282104,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 58, 124, 105],
#             [ 59, 125, 106],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 147, 122],
#             [ 63, 147, 122],
#             [ 62, 146, 121]],
#
#            [[ 58, 124, 105],
#             [ 58, 124, 105],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 147, 122],
#             [ 63, 148, 120],
#             [ 62, 146, 121]],
#
#            [[ 58, 124, 105],
#             [ 58, 124, 105],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 148, 120],
#             [ 63, 149, 119],
#             [ 62, 147, 119]],
#
#            ...,
#
#            [[ 39, 127,  97],
#             [ 38, 128,  98],
#             [ 39, 129,  99],
#             ...,
#             [ 78, 159, 120],
#             [ 78, 159, 120],
#             [ 77, 156, 117]],
#
#            [[ 39, 127,  97],
# ...
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 23996,
#     'bbox': [432, 276, 265, 174],
#     'predicted_iou': 0.9191051721572876,
#     'point_coords': [[480.0, 319.921875]],
#     'stability_score': 0.9680488705635071,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 70, 131, 105],
#             [ 72, 130, 106],
#             [ 71, 129, 105],
#             ...,
#             [ 51, 128,  94],
#             [ 51, 128,  94],
#             [ 58, 136,  99]],
#
#            [[ 67, 128, 102],
#             [ 69, 127, 103],
#             [ 69, 127, 103],
#             ...,
#             [ 50, 127,  93],
#             [ 50, 127,  93],
#             [ 56, 134,  97]],
#
#            [[ 68, 129, 101],
#             [ 70, 128, 103],
#             [ 71, 129, 104],
#             ...,
#             [ 51, 128,  94],
#             [ 51, 128,  94],
#             [ 55, 133,  96]],
#
#            ...,
#
#            [[200, 189, 169],
#             [200, 189, 169],
#             [203, 189, 170],
#             ...,
#             [124, 194, 177],
#             [125, 196, 179],
#             [136, 207, 190]],
#
#            [[201, 191, 173],
#             [201, 191, 173],
#             [203, 191, 173],
#             ...,
#             [115, 184, 164],
#             [123, 193, 176],
#             [128, 198, 181]],
#
#            [[204, 194, 176],
#             [204, 194, 176],
#             [203, 193, 175],
#             ...,
#             [104, 171, 150],
#             [114, 183, 163],
#             [117, 185, 168]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 4388,
#     'bbox': [724, 960, 132, 129],
#     'predicted_iou': 0.9181946516036987,
#     'point_coords': [[800.0, 1045.078125]],
#     'stability_score': 0.9663677215576172,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[120, 196, 172],
#             [119, 194, 172],
#             [119, 190, 173],
#             ...,
#             [110, 238, 209],
#             [112, 240, 211],
#             [116, 246, 216]],
#
#            [[121, 195, 171],
#             [120, 192, 172],
#             [121, 191, 174],
#             ...,
#             [111, 237, 208],
#             [112, 238, 209],
#             [114, 242, 213]],
#
#            [[120, 194, 170],
#             [120, 192, 172],
#             [121, 191, 174],
#             ...,
#             [115, 243, 214],
#             [114, 242, 213],
#             [118, 246, 217]],
#
#            ...,
#
#            [[ 44,  62,  61],
#             [ 42,  60,  59],
#             [ 40,  58,  57],
#             ...,
#             [158, 204, 212],
#             [156, 198, 205],
#             [152, 195, 198]],
#
#            [[ 46,  64,  63],
#             [ 43,  61,  60],
#             [ 40,  58,  57],
#             ...,
#             [158, 202, 209],
#             [156, 198, 203],
#             [154, 195, 197]],
#
#            [[ 42,  60,  61],
#             [ 42,  60,  61],
#             [ 43,  61,  62],
#             ...,
#             [166, 206, 211],
#             [161, 200, 202],
#             [157, 196, 194]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3233,
#     'bbox': [1466, 187, 74, 67],
#     'predicted_iou': 0.9126861691474915,
#     'point_coords': [[1504.0, 234.609375]],
#     'stability_score': 0.9695956110954285,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[152, 193, 225],
#             [152, 193, 225],
#             [151, 192, 224],
#             ...,
#             [152, 188, 218],
#             [150, 186, 216],
#             [148, 184, 214]],
#
#            [[153, 194, 226],
#             [153, 194, 226],
#             [153, 194, 226],
#             ...,
#             [154, 188, 218],
#             [153, 187, 217],
#             [151, 185, 215]],
#
#            [[153, 194, 226],
#             [153, 194, 226],
#             [153, 194, 226],
#             ...,
#             [154, 188, 218],
#             [153, 187, 217],
#             [152, 186, 216]],
#
#            ...,
#
#            [[126, 169, 188],
#             [126, 170, 187],
#             [125, 170, 184],
#             ...,
#             [156, 200, 224],
#             [156, 200, 224],
#             [156, 200, 224]],
#
#            [[129, 172, 191],
#             [128, 172, 189],
#             [126, 171, 185],
#             ...,
#             [155, 198, 225],
#             [155, 198, 225],
#             [156, 199, 226]],
#
#            [[130, 173, 192],
#             [130, 174, 191],
#             [128, 173, 187],
#             ...,
#             [154, 197, 224],
#             [154, 197, 224],
#             [155, 198, 225]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1586,
#     'bbox': [1477, 980, 79, 36],
#     'predicted_iou': 0.9050238728523254,
#     'point_coords': [[1504.0, 1002.421875]],
#     'stability_score': 0.9592592716217041,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 30, 152, 116],
#             [ 34, 156, 120],
#             [ 40, 162, 126],
#             ...,
#             [ 73, 142, 129],
#             [ 79, 145, 133],
#             [ 83, 149, 137]],
#
#            [[ 32, 154, 118],
#             [ 35, 157, 121],
#             [ 32, 154, 118],
#             ...,
#             [ 65, 127, 115],
#             [ 68, 130, 118],
#             [ 71, 131, 120]],
#
#            [[ 34, 156, 120],
#             [ 39, 161, 125],
#             [ 33, 155, 119],
#             ...,
#             [ 63, 124, 110],
#             [ 64, 125, 111],
#             [ 68, 127, 113]],
#
#            ...,
#
#            [[ 78, 122, 105],
#             [ 74, 113,  98],
#             [ 86, 122, 106],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]],
#
#            [[ 76, 114,  96],
#             [ 76, 109,  94],
#             [ 76, 108,  91],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]],
#
#            [[ 73, 105,  88],
#             [ 74, 103,  87],
#             [ 70,  97,  81],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 14686,
#     'bbox': [176, 82, 237, 155],
#     'predicted_iou': 0.8977618217468262,
#     'point_coords': [[288.0, 191.953125]],
#     'stability_score': 0.9581972360610962,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 88, 217, 186],
#             [ 86, 219, 187],
#             [ 86, 219, 187],
#             ...,
#             [ 75, 177, 166],
#             [ 74, 179, 166],
#             [ 76, 180, 169]],
#
#            [[ 83, 213, 182],
#             [ 81, 214, 182],
#             [ 81, 214, 182],
#             ...,
#             [ 73, 178, 167],
#             [ 74, 179, 168],
#             [ 72, 180, 168]],
#
#            [[ 86, 216, 186],
#             [ 84, 216, 186],
#             [ 80, 214, 184],
#             ...,
#             [ 71, 180, 171],
#             [ 72, 181, 172],
#             [ 73, 182, 173]],
#
#            ...,
#
#            [[ 67, 153, 141],
#             [ 65, 153, 139],
#             [ 62, 150, 136],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]],
#
#            [[ 65, 151, 139],
#             [ 63, 151, 137],
#             [ 61, 149, 135],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]],
#
#            [[ 63, 149, 137],
#             [ 61, 149, 135],
#             [ 61, 149, 135],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 25491,
#     'bbox': [397, 106, 260, 171],
#     'predicted_iou': 0.8904027938842773,
#     'point_coords': [[416.0, 149.296875]],
#     'stability_score': 0.9610479474067688,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 52, 165, 155],
#             [ 52, 165, 155],
#             [ 52, 165, 155],
#             ...,
#             [ 78, 133, 116],
#             [ 72, 127, 110],
#             [ 72, 126, 109]],
#
#            [[ 51, 164, 154],
#             [ 53, 166, 156],
#             [ 55, 168, 158],
#             ...,
#             [ 77, 132, 115],
#             [ 69, 124, 107],
#             [ 73, 127, 110]],
#
#            [[ 49, 163, 150],
#             [ 52, 164, 154],
#             [ 53, 165, 155],
#             ...,
#             [ 75, 130, 113],
#             [ 67, 122, 105],
#             [ 74, 128, 111]],
#
#            ...,
#
#            [[ 76, 191, 152],
#             [ 76, 189, 151],
#             [ 74, 189, 150],
#             ...,
#             [ 70, 124, 101],
#             [ 69, 125, 102],
#             [ 66, 124, 100]],
#
#            [[ 81, 194, 156],
#             [ 80, 193, 155],
#             [ 79, 192, 154],
#             ...,
#             [ 70, 121, 101],
#             [ 69, 122, 102],
#             [ 67, 123, 100]],
#
#            [[ 85, 198, 160],
#             [ 85, 196, 158],
#             [ 84, 195, 157],
#             ...,
#             [ 67, 115,  97],
#             [ 65, 116,  96],
#             [ 70, 122,  99]]], dtype=uint8),
#     'leaf_probability': 1}]],
#  'SAM + ResNet': [[{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 111353,
#     'bbox': [351, 0, 390, 515],
#     'predicted_iou': 0.9743954539299011,
#     'point_coords': [[480.0, 106.640625]],
#     'stability_score': 0.9722618460655212,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17989,
#     'bbox': [1753, 1230, 160, 134],
#     'predicted_iou': 0.9417983889579773,
#     'point_coords': [[1888.0, 1343.671875]],
#     'stability_score': 0.9593504667282104,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 12752,
#     'bbox': [604, 1084, 206, 111],
#     'predicted_iou': 0.928359866142273,
#     'point_coords': [[736.0, 1173.046875]],
#     'stability_score': 0.9619406461715698,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9280,
#     'bbox': [0, 1244, 146, 96],
#     'predicted_iou': 0.9088813662528992,
#     'point_coords': [[32.0, 1258.359375]],
#     'stability_score': 0.9625832438468933,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3773,
#     'bbox': [0, 1174, 63, 72],
#     'predicted_iou': 0.8867016434669495,
#     'point_coords': [[32.0, 1215.703125]],
#     'stability_score': 0.9557682275772095,
#     'crop_box': [0, 0, 2048, 1365]}],
#   [{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 5949,
#     'bbox': [423, 1030, 95, 92],
#     'predicted_iou': 0.9647201895713806,
#     'point_coords': [[480.0, 1045.078125]],
#     'stability_score': 0.9805454015731812,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 2426,
#     'bbox': [417, 1203, 45, 64],
#     'predicted_iou': 0.9475746154785156,
#     'point_coords': [[416.0, 1215.703125]],
#     'stability_score': 0.9836199879646301,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3233,
#     'bbox': [1466, 187, 74, 67],
#     'predicted_iou': 0.9126861691474915,
#     'point_coords': [[1504.0, 234.609375]],
#     'stability_score': 0.9695956110954285,
#     'crop_box': [0, 0, 2048, 1365]}]],
#  'Mask R-CNN': [None, None]}

# %%
stage2_names = ["InceptionV3", "VGG19", "MobileNetV3Large"]

# %%
stage2_dict = {
    name: keras.models.load_model(get_latest_checkpoint(f"../disease_detection/checkpoints/{name}_rgb")) 
    for name in stage2_names 
    if get_latest_checkpoint(f"../disease_detection/checkpoints/{name}_rgb") is not None
}
# Out:
# I0000 00:00:1730754578.551342 1916614 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38178 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0

# %%
stage2_dict.keys()
# Out:
# dict_keys(['InceptionV3', 'VGG19', 'MobileNetV3Large'])

# %%
stage1_results
# Out:
# {'SAM + YOLOv8': [[{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1023044,
#     'bbox': [416, 110, 1464, 1052],
#     'predicted_iou': 1.036436915397644,
#     'point_coords': [[1248.0, 703.828125]],
#     'stability_score': 0.9924018979072571,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 67, 103, 119],
#             [ 67, 103, 119],
#             [ 67, 103, 119],
#             ...,
#             [187, 228, 220],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            [[ 69, 103, 119],
#             [ 69, 103, 119],
#             [ 69, 103, 119],
#             ...,
#             [187, 228, 220],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            [[ 69, 102, 118],
#             [ 69, 102, 118],
#             [ 69, 102, 118],
#             ...,
#             [186, 229, 218],
#             [187, 229, 218],
#             [187, 229, 218]],
#
#            ...,
#
#            [[ 74, 151, 123],
#             [ 74, 152, 121],
#             [ 73, 150, 122],
#             ...,
#             [ 94, 166, 153],
#             [ 94, 166, 153],
#             [ 94, 166, 153]],
#
#            [[ 78, 153, 125],
#             [ 78, 153, 125],
#             [ 78, 153, 125],
#             ...,
#             [ 94, 166, 153],
#             [ 94, 166, 153],
#             [ 94, 166, 153]],
#
#            [[ 78, 153, 125],
#             [ 78, 153, 125],
#             [ 78, 153, 125],
#             ...,
#             [ 93, 165, 152],
#             [ 94, 166, 153],
#             [ 94, 166, 153]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 66540,
#     'bbox': [1362, 0, 403, 267],
#     'predicted_iou': 1.0057369470596313,
#     'point_coords': [[1440.0, 21.328125]],
#     'stability_score': 0.9905040860176086,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            [[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            [[ 57, 116,  95],
#             [ 56, 115,  94],
#             [ 56, 116,  92],
#             ...,
#             [ 65, 157, 122],
#             [ 65, 157, 122],
#             [ 65, 155, 119]],
#
#            ...,
#
#            [[ 83, 142, 104],
#             [ 85, 142, 104],
#             [ 85, 142, 104],
#             ...,
#             [ 38,  80,  69],
#             [ 39,  81,  70],
#             [ 38,  80,  69]],
#
#            [[ 87, 144, 106],
#             [ 86, 143, 105],
#             [ 85, 142, 104],
#             ...,
#             [ 38,  80,  69],
#             [ 39,  81,  70],
#             [ 38,  80,  69]],
#
#            [[ 89, 146, 108],
#             [ 88, 145, 107],
#             [ 87, 144, 106],
#             ...,
#             [ 38,  80,  69],
#             [ 38,  80,  69],
#             [ 38,  80,  69]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 106647,
#     'bbox': [0, 899, 623, 428],
#     'predicted_iou': 0.9949654340744019,
#     'point_coords': [[480.0, 959.765625]],
#     'stability_score': 0.9745847582817078,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 54, 119,  98],
#             [ 55, 120,  99],
#             [ 55, 120,  99],
#             ...,
#             [ 46, 121,  77],
#             [ 48, 121,  75],
#             [ 47, 119,  76]],
#
#            [[ 56, 121, 100],
#             [ 56, 121, 100],
#             [ 57, 122, 101],
#             ...,
#             [ 46, 122,  80],
#             [ 47, 122,  78],
#             [ 45, 119,  77]],
#
#            [[ 57, 122, 101],
#             [ 58, 123, 102],
#             [ 59, 124, 103],
#             ...,
#             [ 49, 125,  84],
#             [ 47, 123,  81],
#             [ 45, 121,  79]],
#
#            ...,
#
#            [[129, 183, 176],
#             [129, 183, 176],
#             [129, 183, 176],
#             ...,
#             [ 45, 115,  84],
#             [ 47, 117,  86],
#             [ 47, 120,  88]],
#
#            [[127, 181, 174],
#             [126, 180, 173],
#             [126, 180, 173],
#             ...,
#             [ 45, 115,  84],
#             [ 48, 118,  87],
#             [ 48, 121,  89]],
#
#            [[123, 177, 170],
#             [122, 176, 169],
#             [122, 176, 169],
#             ...,
#             [ 45, 115,  84],
#             [ 48, 118,  87],
#             [ 48, 121,  89]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 52478,
#     'bbox': [0, 377, 220, 476],
#     'predicted_iou': 0.9941893815994263,
#     'point_coords': [[32.0, 746.484375]],
#     'stability_score': 0.9825999736785889,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 63, 163, 145],
#             [ 72, 171, 151],
#             [ 81, 173, 156],
#             ...,
#             [ 31,  53,  58],
#             [ 32,  54,  59],
#             [ 33,  55,  60]],
#
#            [[ 56, 157, 136],
#             [ 67, 167, 145],
#             [ 79, 174, 154],
#             ...,
#             [ 32,  54,  59],
#             [ 31,  56,  60],
#             [ 31,  56,  60]],
#
#            [[ 48, 148, 126],
#             [ 59, 157, 133],
#             [ 71, 166, 145],
#             ...,
#             [ 33,  55,  60],
#             [ 31,  56,  60],
#             [ 32,  57,  61]],
#
#            ...,
#
#            [[ 47, 128, 109],
#             [ 47, 129, 107],
#             [ 48, 128, 105],
#             ...,
#             [ 70, 135, 120],
#             [ 70, 135, 120],
#             [ 70, 135, 120]],
#
#            [[ 48, 127, 108],
#             [ 48, 127, 108],
#             [ 47, 126, 105],
#             ...,
#             [ 71, 136, 121],
#             [ 71, 136, 121],
#             [ 71, 136, 121]],
#
#            [[ 49, 125, 107],
#             [ 48, 124, 106],
#             [ 47, 124, 103],
#             ...,
#             [ 72, 137, 122],
#             [ 72, 137, 122],
#             [ 72, 137, 122]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ...,  True,  True,  True],
#            [False, False, False, ...,  True,  True,  True],
#            [False, False, False, ...,  True,  True,  True],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9946,
#     'bbox': [1887, 0, 160, 94],
#     'predicted_iou': 0.9912731051445007,
#     'point_coords': [[1952.0, 21.328125]],
#     'stability_score': 0.9862275719642639,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 69, 126,  95],
#             [ 68, 126,  97],
#             [ 69, 129,  99],
#             ...,
#             [123, 207, 183],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            [[ 68, 125,  94],
#             [ 68, 126,  97],
#             [ 68, 128,  98],
#             ...,
#             [123, 207, 183],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            [[ 67, 124,  93],
#             [ 68, 126,  97],
#             [ 69, 127,  98],
#             ...,
#             [122, 206, 182],
#             [122, 206, 182],
#             [122, 206, 182]],
#
#            ...,
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 83, 158, 126],
#             [ 81, 157, 125],
#             [ 82, 157, 125]],
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 84, 157, 125],
#             [ 82, 157, 125],
#             [ 83, 156, 124]],
#
#            [[195, 226, 217],
#             [194, 227, 220],
#             [194, 227, 220],
#             ...,
#             [ 85, 158, 126],
#             [ 84, 157, 125],
#             [ 84, 157, 125]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 173063,
#     'bbox': [572, 0, 1201, 370],
#     'predicted_iou': 0.9882864356040955,
#     'point_coords': [[672.0, 63.984375]],
#     'stability_score': 0.9787916541099548,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 60, 139, 100],
#             [ 57, 136,  97],
#             [ 54, 131,  93]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 61, 140, 101],
#             [ 57, 136,  97],
#             [ 55, 132,  94]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 39,  84,  65],
#             ...,
#             [ 61, 139, 102],
#             [ 58, 136,  99],
#             [ 55, 132,  94]],
#
#            ...,
#
#            [[ 55,  93, 111],
#             [ 54,  94, 112],
#             [ 56,  94, 112],
#             ...,
#             [ 90, 167, 129],
#             [ 91, 168, 130],
#             [ 91, 168, 130]],
#
#            [[ 57,  93, 109],
#             [ 55,  94, 109],
#             [ 57,  93, 109],
#             ...,
#             [ 91, 166, 128],
#             [ 92, 167, 129],
#             [ 92, 166, 130]],
#
#            [[ 57,  94, 108],
#             [ 57,  94, 108],
#             [ 57,  94, 108],
#             ...,
#             [ 92, 167, 129],
#             [ 92, 167, 129],
#             [ 94, 166, 130]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[ True,  True,  True, ..., False, False, False],
#            [ True,  True,  True, ..., False, False, False],
#            [ True,  True,  True, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 40697,
#     'bbox': [0, 0, 202, 365],
#     'predicted_iou': 0.9865459203720093,
#     'point_coords': [[32.0, 191.953125]],
#     'stability_score': 0.9808867573738098,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            [[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            [[ 16,  50,  39],
#             [ 16,  50,  39],
#             [ 16,  52,  40],
#             ...,
#             [ 59, 105,  93],
#             [ 59, 104,  95],
#             [ 59, 104,  95]],
#
#            ...,
#
#            [[ 56, 103,  87],
#             [ 53, 100,  84],
#             [ 50,  97,  81],
#             ...,
#             [ 39,  49,  59],
#             [ 37,  47,  57],
#             [ 37,  47,  57]],
#
#            [[ 56, 103,  87],
#             [ 54, 101,  85],
#             [ 50,  97,  81],
#             ...,
#             [ 38,  48,  58],
#             [ 37,  47,  57],
#             [ 37,  47,  57]],
#
#            [[ 59, 104,  88],
#             [ 57, 102,  86],
#             [ 53,  97,  84],
#             ...,
#             [ 38,  48,  58],
#             [ 37,  47,  57],
#             [ 36,  46,  56]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 172784,
#     'bbox': [572, 0, 829, 368],
#     'predicted_iou': 0.9853312373161316,
#     'point_coords': [[1248.0, 63.984375]],
#     'stability_score': 0.9801424741744995,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 59, 121,  85]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 38,  83,  64],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 59, 121,  85]],
#
#            [[ 40,  84,  67],
#             [ 39,  83,  66],
#             [ 39,  84,  65],
#             ...,
#             [ 58, 120,  84],
#             [ 58, 120,  84],
#             [ 60, 121,  87]],
#
#            ...,
#
#            [[ 53,  93, 112],
#             [ 53,  93, 112],
#             [ 53,  93, 112],
#             ...,
#             [ 87, 150, 110],
#             [ 86, 152, 111],
#             [ 88, 156, 115]],
#
#            [[ 53,  93, 112],
#             [ 53,  93, 112],
#             [ 54,  94, 113],
#             ...,
#             [ 88, 151, 111],
#             [ 86, 152, 111],
#             [ 85, 153, 112]],
#
#            [[ 55,  93, 111],
#             [ 54,  94, 112],
#             [ 56,  94, 112],
#             ...,
#             [ 91, 153, 113],
#             [ 90, 153, 113],
#             [ 87, 153, 112]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 34412,
#     'bbox': [940, 1167, 275, 197],
#     'predicted_iou': 0.9822528958320618,
#     'point_coords': [[1056.0, 1215.703125]],
#     'stability_score': 0.9664067029953003,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 24, 100,  58],
#             [ 24, 100,  59],
#             [ 24, 100,  59],
#             ...,
#             [114, 159, 163],
#             [113, 158, 162],
#             [112, 157, 161]],
#
#            [[ 31, 100,  63],
#             [ 32, 101,  64],
#             [ 32, 101,  64],
#             ...,
#             [116, 158, 163],
#             [116, 158, 163],
#             [115, 157, 162]],
#
#            [[ 35,  99,  64],
#             [ 35,  99,  64],
#             [ 36, 100,  65],
#             ...,
#             [117, 159, 164],
#             [116, 158, 163],
#             [116, 158, 163]],
#
#            ...,
#
#            [[ 65, 132, 101],
#             [ 66, 133, 102],
#             [ 68, 135, 104],
#             ...,
#             [103, 163, 157],
#             [103, 163, 157],
#             [103, 162, 158]],
#
#            [[ 65, 132, 101],
#             [ 65, 132, 101],
#             [ 67, 134, 103],
#             ...,
#             [103, 163, 157],
#             [103, 163, 157],
#             [103, 162, 158]],
#
#            [[ 64, 131, 100],
#             [ 65, 132, 101],
#             [ 67, 134, 103],
#             ...,
#             [104, 164, 158],
#             [103, 163, 157],
#             [103, 162, 158]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1185650,
#     'bbox': [0, 110, 1873, 1217],
#     'predicted_iou': 0.9766499996185303,
#     'point_coords': [[1632.0, 746.484375]],
#     'stability_score': 0.958342432975769,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 40, 108,  83],
#             [ 40, 108,  83],
#             [ 40, 109,  82],
#             ...,
#             [180, 227, 218],
#             [180, 227, 218],
#             [186, 229, 220]],
#
#            [[ 40, 108,  83],
#             [ 38, 109,  83],
#             [ 40, 109,  82],
#             ...,
#             [178, 228, 218],
#             [180, 227, 218],
#             [184, 229, 220]],
#
#            [[ 39, 110,  83],
#             [ 37, 111,  83],
#             [ 38, 109,  82],
#             ...,
#             [176, 228, 218],
#             [178, 228, 218],
#             [180, 228, 216]],
#
#            ...,
#
#            [[129, 183, 176],
#             [129, 183, 176],
#             [129, 183, 176],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]],
#
#            [[127, 181, 174],
#             [126, 180, 173],
#             [126, 180, 173],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]],
#
#            [[123, 177, 170],
#             [122, 176, 169],
#             [122, 176, 169],
#             ...,
#             [ 72, 188, 151],
#             [ 72, 188, 151],
#             [ 71, 187, 150]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 14090,
#     'bbox': [1690, 122, 127, 174],
#     'predicted_iou': 0.9752795696258545,
#     'point_coords': [[1760.0, 149.296875]],
#     'stability_score': 0.9783264398574829,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[111, 175, 163],
#             [113, 177, 165],
#             [112, 178, 166],
#             ...,
#             [ 72, 157, 137],
#             [ 73, 158, 138],
#             [ 75, 162, 142]],
#
#            [[111, 175, 163],
#             [113, 177, 165],
#             [112, 178, 166],
#             ...,
#             [ 72, 157, 137],
#             [ 72, 157, 137],
#             [ 75, 162, 142]],
#
#            [[111, 175, 163],
#             [112, 176, 164],
#             [111, 177, 165],
#             ...,
#             [ 71, 156, 136],
#             [ 72, 157, 137],
#             [ 77, 162, 142]],
#
#            ...,
#
#            [[ 27,  97,  60],
#             [ 27,  97,  60],
#             [ 28,  98,  61],
#             ...,
#             [ 63, 160, 134],
#             [ 63, 160, 134],
#             [ 70, 167, 141]],
#
#            [[ 29,  98,  61],
#             [ 30,  99,  62],
#             [ 31, 100,  63],
#             ...,
#             [ 70, 169, 143],
#             [ 69, 170, 144],
#             [ 78, 179, 154]],
#
#            [[ 27,  96,  59],
#             [ 27,  96,  59],
#             [ 28,  97,  60],
#             ...,
#             [ 78, 179, 153],
#             [ 80, 181, 155],
#             [ 87, 189, 164]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 404451,
#     'bbox': [1280, 456, 767, 904],
#     'predicted_iou': 0.9751681685447693,
#     'point_coords': [[1952.0, 789.140625]],
#     'stability_score': 0.9565773606300354,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 98, 156, 115],
#             [100, 158, 117],
#             [103, 161, 120],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            [[ 98, 156, 115],
#             [ 99, 157, 116],
#             [101, 159, 118],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            [[ 98, 158, 117],
#             [ 98, 158, 117],
#             [ 98, 158, 117],
#             ...,
#             [ 97, 206, 167],
#             [ 97, 206, 167],
#             [ 97, 206, 167]],
#
#            ...,
#
#            [[142, 180, 204],
#             [142, 180, 204],
#             [140, 181, 204],
#             ...,
#             [ 87, 174, 140],
#             [ 87, 174, 140],
#             [ 87, 174, 140]],
#
#            [[140, 181, 204],
#             [140, 181, 204],
#             [140, 181, 204],
#             ...,
#             [ 86, 173, 139],
#             [ 87, 174, 140],
#             [ 87, 174, 140]],
#
#            [[140, 181, 204],
#             [140, 181, 204],
#             [140, 181, 204],
#             ...,
#             [ 86, 173, 139],
#             [ 87, 174, 140],
#             [ 87, 174, 140]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 54606,
#     'bbox': [239, 1181, 361, 182],
#     'predicted_iou': 0.9717997908592224,
#     'point_coords': [[288.0, 1301.015625]],
#     'stability_score': 0.9778668284416199,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 66, 143, 115],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [134, 184, 180],
#             [133, 183, 179],
#             [133, 183, 179]],
#
#            [[ 64, 144, 113],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [134, 184, 180],
#             [134, 184, 180],
#             [133, 183, 179]],
#
#            [[ 64, 144, 113],
#             [ 66, 144, 113],
#             [ 66, 144, 113],
#             ...,
#             [135, 185, 181],
#             [134, 184, 180],
#             [134, 184, 180]],
#
#            ...,
#
#            [[ 59, 132, 100],
#             [ 57, 132, 100],
#             [ 56, 132, 100],
#             ...,
#             [ 29,  87,  58],
#             [ 32,  92,  62],
#             [ 32,  94,  64]],
#
#            [[ 59, 131, 101],
#             [ 57, 131, 101],
#             [ 57, 131, 101],
#             ...,
#             [ 30,  90,  60],
#             [ 33,  93,  63],
#             [ 31,  95,  65]],
#
#            [[ 59, 131, 101],
#             [ 57, 131, 101],
#             [ 57, 131, 101],
#             ...,
#             [ 31,  91,  61],
#             [ 35,  95,  65],
#             [ 33,  97,  67]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 44175,
#     'bbox': [1106, 1153, 333, 210],
#     'predicted_iou': 0.9715837240219116,
#     'point_coords': [[1248.0, 1215.703125]],
#     'stability_score': 0.9528433084487915,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 75, 187, 157],
#             [ 75, 181, 158],
#             [ 74, 169, 155],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 35,  90,  73]],
#
#            [[ 85, 195, 167],
#             [ 85, 188, 167],
#             [ 81, 175, 164],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 35,  90,  73]],
#
#            [[ 90, 196, 173],
#             [ 91, 190, 174],
#             [ 87, 178, 169],
#             ...,
#             [ 35,  93,  75],
#             [ 34,  92,  74],
#             [ 36,  91,  74]],
#
#            ...,
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 55, 146, 113],
#             [ 54, 148, 114],
#             [ 54, 148, 114]],
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 53, 147, 113],
#             [ 54, 148, 114],
#             [ 54, 148, 114]],
#
#            [[143, 190, 174],
#             [143, 190, 174],
#             [141, 190, 174],
#             ...,
#             [ 54, 148, 114],
#             [ 54, 148, 114],
#             [ 54, 148, 114]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9005,
#     'bbox': [276, 1181, 165, 94],
#     'predicted_iou': 0.9704208374023438,
#     'point_coords': [[352.0, 1258.359375]],
#     'stability_score': 0.9735687375068665,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 59, 135, 104],
#             [ 59, 135, 104],
#             [ 59, 134, 106],
#             ...,
#             [ 89, 160, 134],
#             [ 89, 160, 134],
#             [ 89, 159, 136]],
#
#            [[ 59, 135, 104],
#             [ 59, 135, 104],
#             [ 58, 133, 105],
#             ...,
#             [ 89, 160, 134],
#             [ 89, 160, 134],
#             [ 89, 159, 136]],
#
#            [[ 59, 135, 104],
#             [ 58, 134, 103],
#             [ 58, 133, 105],
#             ...,
#             [ 87, 160, 134],
#             [ 87, 160, 134],
#             [ 87, 159, 136]],
#
#            ...,
#
#            [[ 86, 160, 132],
#             [ 89, 159, 128],
#             [ 91, 160, 127],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]],
#
#            [[ 85, 159, 129],
#             [ 87, 157, 126],
#             [ 89, 158, 125],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]],
#
#            [[ 83, 157, 127],
#             [ 86, 156, 125],
#             [ 87, 156, 123],
#             ...,
#             [ 33,  95,  59],
#             [ 33,  95,  59],
#             [ 34,  96,  60]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 28032,
#     'bbox': [0, 857, 236, 164],
#     'predicted_iou': 0.9703064560890198,
#     'point_coords': [[96.0, 874.453125]],
#     'stability_score': 0.9763349294662476,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 51, 116, 101],
#             [ 50, 115, 100],
#             [ 48, 113,  97],
#             ...,
#             [ 56, 116,  98],
#             [ 57, 115,  97],
#             [ 55, 113,  95]],
#
#            [[ 49, 111,  99],
#             [ 47, 109,  95],
#             [ 45, 108,  92],
#             ...,
#             [ 55, 117,  99],
#             [ 56, 116,  98],
#             [ 54, 114,  96]],
#
#            [[ 46, 106,  95],
#             [ 45, 105,  94],
#             [ 43, 104,  90],
#             ...,
#             [ 56, 118, 100],
#             [ 57, 117,  99],
#             [ 55, 115,  97]],
#
#            ...,
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  55,  32],
#             [ 26,  55,  32],
#             [ 26,  55,  32]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 25,  54,  31],
#             [ 26,  55,  32],
#             [ 26,  55,  32]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 25,  54,  31],
#             [ 25,  54,  31],
#             [ 26,  55,  32]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 48764,
#     'bbox': [1753, 462, 252, 309],
#     'predicted_iou': 0.9699550867080688,
#     'point_coords': [[1760.0, 618.515625]],
#     'stability_score': 0.9633088707923889,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 39, 133,  86],
#             [ 39, 133,  86],
#             [ 39, 133,  86],
#             ...,
#             [ 91, 198, 159],
#             [ 91, 198, 159],
#             [ 91, 198, 159]],
#
#            [[ 36, 132,  85],
#             [ 36, 132,  85],
#             [ 39, 133,  86],
#             ...,
#             [ 91, 199, 157],
#             [ 91, 198, 159],
#             [ 91, 198, 159]],
#
#            [[ 34, 133,  85],
#             [ 31, 130,  82],
#             [ 33, 129,  82],
#             ...,
#             [ 89, 200, 156],
#             [ 89, 199, 157],
#             [ 89, 199, 157]],
#
#            ...,
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 73, 150, 112],
#             [ 73, 152, 113],
#             [ 75, 152, 114]],
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 72, 151, 112],
#             [ 72, 151, 112],
#             [ 73, 152, 113]],
#
#            [[ 47, 114,  77],
#             [ 47, 114,  77],
#             [ 46, 113,  76],
#             ...,
#             [ 71, 150, 111],
#             [ 72, 151, 112],
#             [ 73, 152, 113]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 35179,
#     'bbox': [0, 792, 243, 229],
#     'predicted_iou': 0.9653553366661072,
#     'point_coords': [[224.0, 831.796875]],
#     'stability_score': 0.9643674492835999,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 60, 135, 107],
#             [ 58, 135, 107],
#             [ 59, 136, 109],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            [[ 60, 135, 107],
#             [ 60, 135, 107],
#             [ 60, 134, 108],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            [[ 60, 134, 106],
#             [ 59, 134, 106],
#             [ 60, 135, 107],
#             ...,
#             [ 25,  55,  36],
#             [ 25,  55,  36],
#             [ 25,  55,  36]],
#
#            ...,
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]],
#
#            [[ 24,  69,  53],
#             [ 24,  69,  53],
#             [ 24,  69,  53],
#             ...,
#             [ 26,  58,  33],
#             [ 27,  59,  34],
#             [ 28,  60,  35]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9215,
#     'bbox': [1406, 1288, 166, 76],
#     'predicted_iou': 0.9636751413345337,
#     'point_coords': [[1440.0, 1343.671875]],
#     'stability_score': 0.9803119897842407,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[140, 197, 198],
#             [138, 195, 196],
#             [138, 195, 197],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            [[140, 197, 198],
#             [138, 195, 196],
#             [137, 194, 196],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            [[140, 197, 198],
#             [138, 195, 196],
#             [137, 194, 196],
#             ...,
#             [ 57, 129, 109],
#             [ 57, 129, 109],
#             [ 58, 130, 110]],
#
#            ...,
#
#            [[ 60, 137, 116],
#             [ 60, 137, 116],
#             [ 62, 137, 115],
#             ...,
#             [ 44, 101,  76],
#             [ 43, 100,  75],
#             [ 41,  98,  73]],
#
#            [[ 61, 138, 117],
#             [ 60, 137, 116],
#             [ 62, 137, 115],
#             ...,
#             [ 43, 100,  75],
#             [ 42,  99,  74],
#             [ 41,  98,  73]],
#
#            [[ 61, 138, 117],
#             [ 61, 138, 117],
#             [ 63, 138, 116],
#             ...,
#             [ 43, 100,  75],
#             [ 42,  99,  74],
#             [ 41,  98,  73]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 15705,
#     'bbox': [553, 1149, 136, 215],
#     'predicted_iou': 0.9624653458595276,
#     'point_coords': [[672.0, 1301.015625]],
#     'stability_score': 0.9720284342765808,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 99, 174, 153],
#             [100, 175, 154],
#             [101, 176, 155],
#             ...,
#             [ 79, 129, 111],
#             [ 77, 129, 111],
#             [ 78, 130, 112]],
#
#            [[ 99, 174, 153],
#             [100, 175, 154],
#             [101, 176, 155],
#             ...,
#             [ 80, 130, 112],
#             [ 78, 130, 112],
#             [ 78, 130, 112]],
#
#            [[ 99, 174, 153],
#             [102, 174, 154],
#             [103, 175, 155],
#             ...,
#             [ 80, 130, 112],
#             [ 78, 130, 112],
#             [ 76, 131, 112]],
#
#            ...,
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 41, 100,  69],
#             [ 41, 100,  69],
#             [ 43,  97,  68]],
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 41, 100,  69],
#             [ 41, 100,  69],
#             [ 43,  97,  68]],
#
#            [[ 21,  52,  31],
#             [ 21,  52,  31],
#             [ 21,  52,  31],
#             ...,
#             [ 40,  99,  68],
#             [ 40,  99,  68],
#             [ 43,  97,  68]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 55768,
#     'bbox': [0, 1181, 601, 182],
#     'predicted_iou': 0.9620964527130127,
#     'point_coords': [[544.0, 1215.703125]],
#     'stability_score': 0.9600830674171448,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 35, 100,  79],
#             [ 35, 100,  79],
#             [ 35, 100,  78],
#             ...,
#             [133, 183, 179],
#             [133, 183, 179],
#             [131, 182, 175]],
#
#            [[ 34,  99,  77],
#             [ 34,  99,  77],
#             [ 34,  99,  77],
#             ...,
#             [134, 184, 180],
#             [133, 183, 179],
#             [132, 183, 176]],
#
#            [[ 33,  98,  76],
#             [ 33,  98,  76],
#             [ 33,  98,  76],
#             ...,
#             [134, 184, 180],
#             [134, 184, 180],
#             [132, 183, 176]],
#
#            ...,
#
#            [[ 31, 102,  76],
#             [ 32, 103,  77],
#             [ 32, 103,  77],
#             ...,
#             [ 32,  92,  62],
#             [ 32,  94,  64],
#             [ 34,  98,  68]],
#
#            [[ 33, 101,  76],
#             [ 34, 102,  77],
#             [ 34, 102,  77],
#             ...,
#             [ 33,  93,  63],
#             [ 31,  95,  65],
#             [ 35,  99,  69]],
#
#            [[ 33, 101,  76],
#             [ 33, 101,  76],
#             [ 34, 102,  77],
#             ...,
#             [ 35,  95,  65],
#             [ 33,  97,  67],
#             [ 36, 100,  70]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17411,
#     'bbox': [264, 723, 178, 126],
#     'predicted_iou': 0.9590465426445007,
#     'point_coords': [[288.0, 746.484375]],
#     'stability_score': 0.9686352014541626,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[100, 139, 131],
#             [100, 139, 131],
#             [ 99, 138, 130],
#             ...,
#             [ 33, 111,  74],
#             [ 35, 113,  76],
#             [ 35, 114,  75]],
#
#            [[100, 139, 131],
#             [100, 139, 131],
#             [100, 139, 131],
#             ...,
#             [ 33, 110,  73],
#             [ 33, 112,  73],
#             [ 33, 112,  73]],
#
#            [[101, 140, 132],
#             [100, 139, 131],
#             [100, 139, 131],
#             ...,
#             [ 32, 109,  72],
#             [ 32, 111,  72],
#             [ 32, 111,  72]],
#
#            ...,
#
#            [[ 31,  70,  48],
#             [ 31,  70,  48],
#             [ 31,  70,  48],
#             ...,
#             [ 36,  83,  51],
#             [ 33,  80,  48],
#             [ 33,  80,  48]],
#
#            [[ 31,  70,  49],
#             [ 31,  70,  48],
#             [ 31,  70,  49],
#             ...,
#             [ 36,  83,  51],
#             [ 35,  79,  48],
#             [ 32,  79,  47]],
#
#            [[ 29,  69,  51],
#             [ 29,  70,  49],
#             [ 30,  70,  52],
#             ...,
#             [ 35,  80,  47],
#             [ 38,  81,  48],
#             [ 35,  80,  47]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 15150,
#     'bbox': [675, 1107, 376, 161],
#     'predicted_iou': 0.9559239745140076,
#     'point_coords': [[864.0, 1173.046875]],
#     'stability_score': 0.9668028354644775,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 53, 106,  86],
#             [ 56, 107,  87],
#             [ 57, 108,  88],
#             ...,
#             [ 24, 105,  60],
#             [ 24, 105,  60],
#             [ 23, 104,  59]],
#
#            [[ 54, 104,  86],
#             [ 55, 105,  87],
#             [ 56, 106,  88],
#             ...,
#             [ 26, 105,  61],
#             [ 26, 105,  61],
#             [ 25, 104,  60]],
#
#            [[ 54, 104,  86],
#             [ 55, 105,  87],
#             [ 55, 105,  87],
#             ...,
#             [ 26, 105,  61],
#             [ 27, 104,  60],
#             [ 27, 104,  60]],
#
#            ...,
#
#            [[ 63, 145, 103],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [130, 186, 165],
#             [130, 186, 165],
#             [133, 186, 166]],
#
#            [[ 63, 144, 105],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [131, 187, 166],
#             [131, 187, 166],
#             [133, 186, 166]],
#
#            [[ 63, 144, 105],
#             [ 62, 144, 102],
#             [ 61, 143, 101],
#             ...,
#             [132, 188, 167],
#             [132, 188, 167],
#             [134, 187, 167]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 111786,
#     'bbox': [129, 182, 367, 512],
#     'predicted_iou': 0.9550802111625671,
#     'point_coords': [[288.0, 319.921875]],
#     'stability_score': 0.9624460339546204,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 93, 127, 133],
#             [ 96, 130, 136],
#             [ 99, 133, 139],
#             ...,
#             [ 54,  85, 100],
#             [ 53,  84,  99],
#             [ 53,  84,  99]],
#
#            [[ 95, 129, 135],
#             [ 98, 132, 138],
#             [101, 135, 141],
#             ...,
#             [ 54,  85, 100],
#             [ 53,  84,  99],
#             [ 53,  84,  99]],
#
#            [[ 96, 128, 134],
#             [100, 132, 138],
#             [103, 135, 141],
#             ...,
#             [ 54,  85, 100],
#             [ 52,  83,  98],
#             [ 52,  83,  98]],
#
#            ...,
#
#            [[ 32,  99,  60],
#             [ 33, 100,  61],
#             [ 33, 100,  61],
#             ...,
#             [ 28,  92,  57],
#             [ 26,  90,  55],
#             [ 25,  89,  54]],
#
#            [[ 33, 100,  61],
#             [ 33, 100,  61],
#             [ 33, 100,  61],
#             ...,
#             [ 29,  93,  57],
#             [ 27,  91,  55],
#             [ 25,  89,  53]],
#
#            [[ 33, 100,  61],
#             [ 34, 101,  62],
#             [ 34, 101,  62],
#             ...,
#             [ 31,  95,  59],
#             [ 29,  93,  57],
#             [ 27,  92,  53]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17849,
#     'bbox': [38, 798, 360, 206],
#     'predicted_iou': 0.9469700455665588,
#     'point_coords': [[288.0, 959.765625]],
#     'stability_score': 0.9567816853523254,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 51, 147, 106],
#             [ 51, 147, 106],
#             [ 56, 148, 107],
#             ...,
#             [ 35, 103,  62],
#             [ 35, 103,  62],
#             [ 35, 103,  62]],
#
#            [[ 53, 147, 106],
#             [ 53, 147, 106],
#             [ 56, 148, 107],
#             ...,
#             [ 35, 103,  62],
#             [ 35, 102,  63],
#             [ 34, 102,  61]],
#
#            [[ 55, 147, 106],
#             [ 57, 146, 106],
#             [ 59, 148, 109],
#             ...,
#             [ 32, 102,  62],
#             [ 32, 101,  64],
#             [ 31, 101,  61]],
#
#            ...,
#
#            [[ 48, 100,  77],
#             [ 48, 100,  77],
#             [ 45,  97,  74],
#             ...,
#             [ 61, 131, 108],
#             [ 61, 132, 106],
#             [ 61, 132, 106]],
#
#            [[ 43,  95,  71],
#             [ 44,  96,  72],
#             [ 43,  93,  69],
#             ...,
#             [ 60, 132, 109],
#             [ 60, 133, 107],
#             [ 60, 133, 107]],
#
#            [[ 39,  91,  67],
#             [ 40,  92,  68],
#             [ 39,  89,  65],
#             ...,
#             [ 61, 133, 110],
#             [ 61, 134, 108],
#             [ 61, 134, 108]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17989,
#     'bbox': [1753, 1230, 160, 134],
#     'predicted_iou': 0.9417983889579773,
#     'point_coords': [[1888.0, 1343.671875]],
#     'stability_score': 0.9593504667282104,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 58, 124, 105],
#             [ 59, 125, 106],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 147, 122],
#             [ 63, 147, 122],
#             [ 62, 146, 121]],
#
#            [[ 58, 124, 105],
#             [ 58, 124, 105],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 147, 122],
#             [ 63, 148, 120],
#             [ 62, 146, 121]],
#
#            [[ 58, 124, 105],
#             [ 58, 124, 105],
#             [ 59, 125, 106],
#             ...,
#             [ 63, 148, 120],
#             [ 63, 149, 119],
#             [ 62, 147, 119]],
#
#            ...,
#
#            [[ 39, 127,  97],
#             [ 38, 128,  98],
#             [ 39, 129,  99],
#             ...,
#             [ 78, 159, 120],
#             [ 78, 159, 120],
#             [ 77, 156, 117]],
#
#            [[ 39, 127,  97],
# ...
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 23996,
#     'bbox': [432, 276, 265, 174],
#     'predicted_iou': 0.9191051721572876,
#     'point_coords': [[480.0, 319.921875]],
#     'stability_score': 0.9680488705635071,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 70, 131, 105],
#             [ 72, 130, 106],
#             [ 71, 129, 105],
#             ...,
#             [ 51, 128,  94],
#             [ 51, 128,  94],
#             [ 58, 136,  99]],
#
#            [[ 67, 128, 102],
#             [ 69, 127, 103],
#             [ 69, 127, 103],
#             ...,
#             [ 50, 127,  93],
#             [ 50, 127,  93],
#             [ 56, 134,  97]],
#
#            [[ 68, 129, 101],
#             [ 70, 128, 103],
#             [ 71, 129, 104],
#             ...,
#             [ 51, 128,  94],
#             [ 51, 128,  94],
#             [ 55, 133,  96]],
#
#            ...,
#
#            [[200, 189, 169],
#             [200, 189, 169],
#             [203, 189, 170],
#             ...,
#             [124, 194, 177],
#             [125, 196, 179],
#             [136, 207, 190]],
#
#            [[201, 191, 173],
#             [201, 191, 173],
#             [203, 191, 173],
#             ...,
#             [115, 184, 164],
#             [123, 193, 176],
#             [128, 198, 181]],
#
#            [[204, 194, 176],
#             [204, 194, 176],
#             [203, 193, 175],
#             ...,
#             [104, 171, 150],
#             [114, 183, 163],
#             [117, 185, 168]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 4388,
#     'bbox': [724, 960, 132, 129],
#     'predicted_iou': 0.9181946516036987,
#     'point_coords': [[800.0, 1045.078125]],
#     'stability_score': 0.9663677215576172,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[120, 196, 172],
#             [119, 194, 172],
#             [119, 190, 173],
#             ...,
#             [110, 238, 209],
#             [112, 240, 211],
#             [116, 246, 216]],
#
#            [[121, 195, 171],
#             [120, 192, 172],
#             [121, 191, 174],
#             ...,
#             [111, 237, 208],
#             [112, 238, 209],
#             [114, 242, 213]],
#
#            [[120, 194, 170],
#             [120, 192, 172],
#             [121, 191, 174],
#             ...,
#             [115, 243, 214],
#             [114, 242, 213],
#             [118, 246, 217]],
#
#            ...,
#
#            [[ 44,  62,  61],
#             [ 42,  60,  59],
#             [ 40,  58,  57],
#             ...,
#             [158, 204, 212],
#             [156, 198, 205],
#             [152, 195, 198]],
#
#            [[ 46,  64,  63],
#             [ 43,  61,  60],
#             [ 40,  58,  57],
#             ...,
#             [158, 202, 209],
#             [156, 198, 203],
#             [154, 195, 197]],
#
#            [[ 42,  60,  61],
#             [ 42,  60,  61],
#             [ 43,  61,  62],
#             ...,
#             [166, 206, 211],
#             [161, 200, 202],
#             [157, 196, 194]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3233,
#     'bbox': [1466, 187, 74, 67],
#     'predicted_iou': 0.9126861691474915,
#     'point_coords': [[1504.0, 234.609375]],
#     'stability_score': 0.9695956110954285,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[152, 193, 225],
#             [152, 193, 225],
#             [151, 192, 224],
#             ...,
#             [152, 188, 218],
#             [150, 186, 216],
#             [148, 184, 214]],
#
#            [[153, 194, 226],
#             [153, 194, 226],
#             [153, 194, 226],
#             ...,
#             [154, 188, 218],
#             [153, 187, 217],
#             [151, 185, 215]],
#
#            [[153, 194, 226],
#             [153, 194, 226],
#             [153, 194, 226],
#             ...,
#             [154, 188, 218],
#             [153, 187, 217],
#             [152, 186, 216]],
#
#            ...,
#
#            [[126, 169, 188],
#             [126, 170, 187],
#             [125, 170, 184],
#             ...,
#             [156, 200, 224],
#             [156, 200, 224],
#             [156, 200, 224]],
#
#            [[129, 172, 191],
#             [128, 172, 189],
#             [126, 171, 185],
#             ...,
#             [155, 198, 225],
#             [155, 198, 225],
#             [156, 199, 226]],
#
#            [[130, 173, 192],
#             [130, 174, 191],
#             [128, 173, 187],
#             ...,
#             [154, 197, 224],
#             [154, 197, 224],
#             [155, 198, 225]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 1586,
#     'bbox': [1477, 980, 79, 36],
#     'predicted_iou': 0.9050238728523254,
#     'point_coords': [[1504.0, 1002.421875]],
#     'stability_score': 0.9592592716217041,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 30, 152, 116],
#             [ 34, 156, 120],
#             [ 40, 162, 126],
#             ...,
#             [ 73, 142, 129],
#             [ 79, 145, 133],
#             [ 83, 149, 137]],
#
#            [[ 32, 154, 118],
#             [ 35, 157, 121],
#             [ 32, 154, 118],
#             ...,
#             [ 65, 127, 115],
#             [ 68, 130, 118],
#             [ 71, 131, 120]],
#
#            [[ 34, 156, 120],
#             [ 39, 161, 125],
#             [ 33, 155, 119],
#             ...,
#             [ 63, 124, 110],
#             [ 64, 125, 111],
#             [ 68, 127, 113]],
#
#            ...,
#
#            [[ 78, 122, 105],
#             [ 74, 113,  98],
#             [ 86, 122, 106],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]],
#
#            [[ 76, 114,  96],
#             [ 76, 109,  94],
#             [ 76, 108,  91],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]],
#
#            [[ 73, 105,  88],
#             [ 74, 103,  87],
#             [ 70,  97,  81],
#             ...,
#             [ 22,  46,  34],
#             [ 21,  45,  33],
#             [ 20,  44,  32]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 14686,
#     'bbox': [176, 82, 237, 155],
#     'predicted_iou': 0.8977618217468262,
#     'point_coords': [[288.0, 191.953125]],
#     'stability_score': 0.9581972360610962,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 88, 217, 186],
#             [ 86, 219, 187],
#             [ 86, 219, 187],
#             ...,
#             [ 75, 177, 166],
#             [ 74, 179, 166],
#             [ 76, 180, 169]],
#
#            [[ 83, 213, 182],
#             [ 81, 214, 182],
#             [ 81, 214, 182],
#             ...,
#             [ 73, 178, 167],
#             [ 74, 179, 168],
#             [ 72, 180, 168]],
#
#            [[ 86, 216, 186],
#             [ 84, 216, 186],
#             [ 80, 214, 184],
#             ...,
#             [ 71, 180, 171],
#             [ 72, 181, 172],
#             [ 73, 182, 173]],
#
#            ...,
#
#            [[ 67, 153, 141],
#             [ 65, 153, 139],
#             [ 62, 150, 136],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]],
#
#            [[ 65, 151, 139],
#             [ 63, 151, 137],
#             [ 61, 149, 135],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]],
#
#            [[ 63, 149, 137],
#             [ 61, 149, 135],
#             [ 61, 149, 135],
#             ...,
#             [ 95, 194, 154],
#             [ 95, 194, 154],
#             [ 97, 194, 154]]], dtype=uint8),
#     'leaf_probability': 1},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 25491,
#     'bbox': [397, 106, 260, 171],
#     'predicted_iou': 0.8904027938842773,
#     'point_coords': [[416.0, 149.296875]],
#     'stability_score': 0.9610479474067688,
#     'crop_box': [0, 0, 2048, 1365],
#     'patch': array([[[ 52, 165, 155],
#             [ 52, 165, 155],
#             [ 52, 165, 155],
#             ...,
#             [ 78, 133, 116],
#             [ 72, 127, 110],
#             [ 72, 126, 109]],
#
#            [[ 51, 164, 154],
#             [ 53, 166, 156],
#             [ 55, 168, 158],
#             ...,
#             [ 77, 132, 115],
#             [ 69, 124, 107],
#             [ 73, 127, 110]],
#
#            [[ 49, 163, 150],
#             [ 52, 164, 154],
#             [ 53, 165, 155],
#             ...,
#             [ 75, 130, 113],
#             [ 67, 122, 105],
#             [ 74, 128, 111]],
#
#            ...,
#
#            [[ 76, 191, 152],
#             [ 76, 189, 151],
#             [ 74, 189, 150],
#             ...,
#             [ 70, 124, 101],
#             [ 69, 125, 102],
#             [ 66, 124, 100]],
#
#            [[ 81, 194, 156],
#             [ 80, 193, 155],
#             [ 79, 192, 154],
#             ...,
#             [ 70, 121, 101],
#             [ 69, 122, 102],
#             [ 67, 123, 100]],
#
#            [[ 85, 198, 160],
#             [ 85, 196, 158],
#             [ 84, 195, 157],
#             ...,
#             [ 67, 115,  97],
#             [ 65, 116,  96],
#             [ 70, 122,  99]]], dtype=uint8),
#     'leaf_probability': 1}]],
#  'SAM + ResNet': [[{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 111353,
#     'bbox': [351, 0, 390, 515],
#     'predicted_iou': 0.9743954539299011,
#     'point_coords': [[480.0, 106.640625]],
#     'stability_score': 0.9722618460655212,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 17989,
#     'bbox': [1753, 1230, 160, 134],
#     'predicted_iou': 0.9417983889579773,
#     'point_coords': [[1888.0, 1343.671875]],
#     'stability_score': 0.9593504667282104,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 12752,
#     'bbox': [604, 1084, 206, 111],
#     'predicted_iou': 0.928359866142273,
#     'point_coords': [[736.0, 1173.046875]],
#     'stability_score': 0.9619406461715698,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 9280,
#     'bbox': [0, 1244, 146, 96],
#     'predicted_iou': 0.9088813662528992,
#     'point_coords': [[32.0, 1258.359375]],
#     'stability_score': 0.9625832438468933,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3773,
#     'bbox': [0, 1174, 63, 72],
#     'predicted_iou': 0.8867016434669495,
#     'point_coords': [[32.0, 1215.703125]],
#     'stability_score': 0.9557682275772095,
#     'crop_box': [0, 0, 2048, 1365]}],
#   [{'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 5949,
#     'bbox': [423, 1030, 95, 92],
#     'predicted_iou': 0.9647201895713806,
#     'point_coords': [[480.0, 1045.078125]],
#     'stability_score': 0.9805454015731812,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 2426,
#     'bbox': [417, 1203, 45, 64],
#     'predicted_iou': 0.9475746154785156,
#     'point_coords': [[416.0, 1215.703125]],
#     'stability_score': 0.9836199879646301,
#     'crop_box': [0, 0, 2048, 1365]},
#    {'segmentation': array([[False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            ...,
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False],
#            [False, False, False, ..., False, False, False]]),
#     'area': 3233,
#     'bbox': [1466, 187, 74, 67],
#     'predicted_iou': 0.9126861691474915,
#     'point_coords': [[1504.0, 234.609375]],
#     'stability_score': 0.9695956110954285,
#     'crop_box': [0, 0, 2048, 1365]}]],
#  'Mask R-CNN': [None, None]}

# %%
stage2_results = {}
for stage1_name, stage1_result in stage1_results.items():
    for leaf_masks in stage1_result:
        for leaf_mask in leaf_masks:
            for stage2_name, stage2_model in stage2_dict.items():
                stage2_results[f"{stage1_name} + {stage2_name}"] = []
                inputs = leaf_mask["patch"]
                inputs = cv2.resize(inputs, (224, 224))
                inputs = tf.constant(inputs)
                inputs = tf.expand_dims(inputs, 0)
                prob = stage2_model(inputs)
                if prob > PROB_THRESHOLD:
                    stage2_results[f"{stage1_name} + {stage2_name}"].append(index)
                    results.append(index)
                    print(f"index {index} sick")
# Out:
# E0000 00:00:1730755566.034403 1916614 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# 2024-11-04 22:26:06.034563: W tensorflow/core/framework/op_kernel.cc:1841] OP_REQUIRES failed at conv_ops_impl.h:1204 : INVALID_ARGUMENT: No DNN in stream executor.
# 2024-11-04 22:26:06.034609: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: INVALID_ARGUMENT: No DNN in stream executor.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[68], line 11
#       9 inputs = tf.constant(inputs)
#      10 inputs = tf.expand_dims(inputs, 0)
# ---> 11 prob = stage2_model(inputs)
#      12 if prob > PROB_THRESHOLD:
#      13     stage2_results[f"{stage1_name} + {stage2_name}"].append(index)
#
# File ~/.conda/envs/total/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.conda/envs/total/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Exception encountered when calling Conv2D.call().
#
# {{function_node __wrapped__Conv2D_device_/job:localhost/replica:0/task:0/device:GPU:0}} No DNN in stream executor. [Op:Conv2D]
#
# Arguments received by Conv2D.call():
#   • inputs=tf.Tensor(shape=(1, 224, 224, 3), dtype=float32)
